# %%
# Regular EDA and plotting libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read data
df = pd.read_csv('../data/games_formatted.csv')
# Remove ID of Game
df = df.drop('GAME_ID',axis=1)
df.head()
print(len(df.index))
# Out:
# 21930

# %%
# Remove row that have missing values due to infamillarity with original dataset
print('Before drop',len(df.index),'rows')
games = df.dropna()
print('After drop',len(df.index),'rows')
# Out:
# Before drop 21930 rows
# After drop 21930 rows

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21930 entries, 0 to 21929
# Data columns (total 45 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   G_home                 21922 non-null  float64
#  1   W_PCT_home             21922 non-null  float64
#  2   HOME_RECORD_home       21922 non-null  float64
#  3   ROAD_RECORD_home       21922 non-null  float64
#  4   W_PCT_prev_home        21922 non-null  float64
#  5   HOME_RECORD_prev_home  21922 non-null  float64
#  6   ROAD_RECORD_prev_home  21922 non-null  float64
#  7   G_away                 21920 non-null  float64
#  8   W_PCT_away             21920 non-null  float64
#  9   HOME_RECORD_away       21920 non-null  float64
#  10  ROAD_RECORD_away       21920 non-null  float64
#  11  W_PCT_prev_away        21920 non-null  float64
#  12  HOME_RECORD_prev_away  21920 non-null  float64
#  13  ROAD_RECORD_prev_away  21920 non-null  float64
#  14  WIN_PRCT_home_3g       21930 non-null  float64
#  15  PTS_home_3g            21930 non-null  float64
#  16  FG_PCT_home_3g         21930 non-null  float64
#  17  FT_PCT_home_3g         21930 non-null  float64
#  18  FG3_PCT_home_3g        21930 non-null  float64
#  19  AST_home_3g            21930 non-null  float64
#  20  REB_home_3g            21930 non-null  float64
#  21  WIN_PRCT_away_3g       21930 non-null  float64
#  22  PTS_away_3g            21930 non-null  float64
#  23  FG_PCT_away_3g         21930 non-null  float64
#  24  FT_PCT_away_3g         21930 non-null  float64
#  25  FG3_PCT_away_3g        21930 non-null  float64
#  26  AST_away_3g            21930 non-null  float64
#  27  REB_away_3g            21930 non-null  float64
#  28  WIN_PRCT_home_10g      21930 non-null  float64
#  29  PTS_home_10g           21930 non-null  float64
#  30  FG_PCT_home_10g        21930 non-null  float64
#  31  FT_PCT_home_10g        21930 non-null  float64
#  32  FG3_PCT_home_10g       21930 non-null  float64
#  33  AST_home_10g           21930 non-null  float64
#  34  REB_home_10g           21930 non-null  float64
#  35  WIN_PRCT_away_10g      21930 non-null  float64
#  36  PTS_away_10g           21930 non-null  float64
#  37  FG_PCT_away_10g        21930 non-null  float64
#  38  FT_PCT_away_10g        21930 non-null  float64
#  39  FG3_PCT_away_10g       21930 non-null  float64
#  40  AST_away_10g           21930 non-null  float64
#  41  REB_away_10g           21930 non-null  float64
#  42  GAME_DATE_EST          21930 non-null  object
#  43  SEASON                 21930 non-null  int64
#  44  HOME_TEAM_WINS         21930 non-null  int64
# dtypes: float64(42), int64(2), object(1)
# memory usage: 7.5+ MB

# %%
df.head()
# Out:
#    G_home  W_PCT_home  HOME_RECORD_home  ROAD_RECORD_home  W_PCT_prev_home  \
# 0    82.0       0.549          0.707317          0.390244            0.305
# 1    82.0       0.524          0.609756          0.439024            0.402
# 2    82.0       0.159          0.219512          0.097561            0.341
# 3    82.0       0.659          0.780488          0.536585            0.659
# 4    82.0       0.610          0.731707          0.487805            0.671
#
#    HOME_RECORD_prev_home  ROAD_RECORD_prev_home  G_away  W_PCT_away  \
# 0               0.414634               0.195122    82.0       0.512
# 1               0.512195               0.292683    82.0       0.622
# 2               0.439024               0.243902    82.0       0.439
# 3               0.756098               0.560976    82.0       0.573
# 4               0.829268               0.512195    82.0       0.707
#
#    HOME_RECORD_away  ...  WIN_PRCT_away_10g  PTS_away_10g  FG_PCT_away_10g  \
# 0          0.707317  ...                0.4          95.8           0.4351
# 1          0.634146  ...                0.6         101.9           0.4859
# 2          0.585366  ...                0.2          97.6           0.4624
# 3          0.658537  ...                0.5         102.1           0.4388
# 4          0.707317  ...                0.5         106.4           0.4555
#
#    FT_PCT_away_10g  FG3_PCT_away_10g  AST_away_10g  REB_away_10g  \
# 0           0.6791            0.3258          22.8          42.7
# 1           0.7998            0.4583          20.5          38.4
# 2           0.6709            0.3665          20.6          41.8
# 3           0.7533            0.4495          23.2          43.7
# 4           0.7801            0.3558          17.6          44.5
#
#    GAME_DATE_EST  SEASON  HOME_TEAM_WINS
# 0     2005-10-10    2005               0
# 1     2005-10-11    2005               0
# 2     2005-10-11    2005               0
# 3     2005-10-11    2005               1
# 4     2005-10-11    2005               0
#
# [5 rows x 45 columns]

# %% [markdown]
# ## Data Exploration (EDA)

# %%
# Let's see how many positive (1) and negative (0) samples we have in our dataframe
df['HOME_TEAM_WINS'].value_counts()
# Out:
# 1    12912
# 0     9018
# Name: HOME_TEAM_WINS, dtype: int64

# %%
df['HOME_TEAM_WINS'].value_counts().plot(kind="bar", color=["salmon", "lightblue"]);

# %%
df.describe()
# Out:
#              G_home    W_PCT_home  HOME_RECORD_home  ROAD_RECORD_home  \
# count  21922.000000  21922.000000      21922.000000      21922.000000
# mean      53.017882      0.508388          0.595489          0.422547
# std       23.515190      0.164096          0.187623          0.176870
# min       10.000000      0.000000          0.000000          0.000000
# 25%       32.000000      0.390000          0.463415          0.292683
# 50%       55.000000      0.512000          0.609756          0.416667
# 75%       77.000000      0.628000          0.731707          0.550000
# max       82.000000      1.000000          1.000000          1.000000
#
#        W_PCT_prev_home  HOME_RECORD_prev_home  ROAD_RECORD_prev_home  \
# count     21922.000000           21922.000000           21922.000000
# mean          0.506033               0.597778               0.414347
# std           0.153251               0.169860               0.155857
# min           0.106000               0.121212               0.073171
# 25%           0.402000               0.487805               0.292683
# 50%           0.512000               0.609756               0.414634
# 75%           0.621000               0.731707               0.536585
# max           0.890000               0.975610               0.829268
#
#              G_away    W_PCT_away  HOME_RECORD_away  ...  REB_home_10g  \
# count  21920.000000  21920.000000      21920.000000  ...  21930.000000
# mean      52.941834      0.509037          0.594324  ...     42.644565
# std       23.510511      0.163100          0.185846  ...      2.982138
# min       10.000000      0.000000          0.000000  ...     32.400000
# 25%       32.000000      0.391000          0.463415  ...     40.600000
# 50%       55.000000      0.512000          0.608696  ...     42.600000
# 75%       76.000000      0.627000          0.731707  ...     44.600000
# max       82.000000      1.000000          1.000000  ...     54.600000
#
#        WIN_PRCT_away_10g  PTS_away_10g  FG_PCT_away_10g  FT_PCT_away_10g  \
# count       21930.000000  21930.000000     21930.000000     21930.000000
# mean            0.502253    102.105942         0.456054         0.759008
# std             0.204379      7.555879         0.023103         0.042826
# min             0.000000     79.900000         0.378700         0.544500
# 25%             0.400000     96.600000         0.440400         0.731100
# 50%             0.500000    101.400000         0.455500         0.761100
# 75%             0.600000    107.100000         0.471600         0.789100
# max             1.000000    131.100000         0.546900         0.893000
#
#        FG3_PCT_away_10g  AST_away_10g  REB_away_10g        SEASON  \
# count      21930.000000  21930.000000  21930.000000  21930.000000
# mean           0.353824     22.078299     42.730351   2012.370771
# std            0.038095      2.745292      2.971854      4.582005
# min            0.191800     13.800000     32.500000   2005.000000
# 25%            0.329200     20.200000     40.700000   2008.000000
# 50%            0.354300     21.900000     42.600000   2012.000000
# 75%            0.378800     23.800000     44.700000   2016.000000
# max            0.507100     34.400000     54.700000   2020.000000
#
#        HOME_TEAM_WINS
# count    21930.000000
# mean         0.588782
# std          0.492066
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
#
# [8 rows x 44 columns]

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(18,6))       
home3g = pd.crosstab(index=df['WIN_PRCT_home_3g'],
                             columns=df['HOME_TEAM_WINS'],
                             normalize="index")
home3g.plot(kind='barh', 
                    stacked=True, 
                    colormap='tab10', 
                    ax=ax1)
h, l = ax1.get_legend_handles_labels()
ax1.legend(h, ['No','Yes'] , title="Home Team Wins")
ax1.set_yticks([3,2,1,0],["1","0.66", "0.33","0.0"])
ax1.set_title("Whether Home Team Wins By Mean Win % on previous 3 games of Home Team")

home10g = pd.crosstab(index=df['WIN_PRCT_home_10g'],
                             columns=df['HOME_TEAM_WINS'],
                             normalize="index")
home10g.plot(kind='barh', 
                    stacked=True, 
                    colormap='tab10', 
                    ax=ax2)
h, l = ax2.get_legend_handles_labels()
ax2.legend(h, ['No','Yes'] , title="Home Team Wins")
ax2.set_title("Whether Home Team Wins By Mean Win % on previous 10 games of Home Team")
plt.show()

# %% [markdown]
# - For stacked bar chart from left side
#     - Looking from bottom to top, the light blue bar increases when the mean Win % on previous 3 games of Home Team increases
# - For stacked bar chart from right side
#     - Looking from bottom to top, the light blue bar increases when the mean Win % on previous 10 games of Home Team increases

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(18,6))       
home3g = pd.crosstab(index=df['WIN_PRCT_away_3g'],
                             columns=df['HOME_TEAM_WINS'],
                             normalize="index")
home3g.plot(kind='barh', 
                    stacked=True, 
                    colormap='tab10', 
                    ax=ax1)
h, l = ax1.get_legend_handles_labels()
ax1.legend(h, ['No','Yes'] , title="Home Team Wins")
ax1.set_yticks([3,2,1,0],["1","0.66", "0.33","0.0"])
ax1.set_title("Whether Home Team Wins By Mean Win % on previous 3 games of Away Team")

home10g = pd.crosstab(index=df['WIN_PRCT_away_10g'],
                             columns=df['HOME_TEAM_WINS'],
                             normalize="index")
home10g.plot(kind='barh', 
                    stacked=True, 
                    colormap='tab10', 
                    ax=ax2)
h, l = ax2.get_legend_handles_labels()
ax2.legend(h, ['No','Yes'] , title="Home Team Wins")
ax2.set_title("Whether Home Team Wins By Mean Win % on previous 10 games of Away Team")
plt.show()

# %% [markdown]
# - For stacked bar chart from left side
#     - Looking from bottom to top, the light blue bar decreases when the mean Win % on previous 3 games of Away Team increases
# - For stacked bar chart from right side
#     - Looking from bottom to top, the light blue bar decreases when the mean Win % on previous 10 games of Away Team increases
#
# - We can conclude that
#     - **Higher** the win % of previous games of home team, the **higher** chances that the home team will win
#     - **Higher** the win % of previous games of away team, the **lower** chances that the home team will win
#     - Which it does make sense

# %%
# Investigate that is the number of previous games for game stats will affect the target variable?
fig, axes = plt.subplots(2,1, figsize=(20,20))


# Start with positve examples
axes[0].scatter(df['FT_PCT_home_3g'][df['HOME_TEAM_WINS']==1], 
            df['FG3_PCT_home_3g'][df['HOME_TEAM_WINS']==1], 
            c="salmon",) 

# Now for negative examples,
axes[0].scatter(df['FT_PCT_home_3g'][df['HOME_TEAM_WINS']==0], 
            df['FG3_PCT_home_3g'][df['HOME_TEAM_WINS']==0], 
            c="lightblue") 


axes[0].set_title("Win/Lose by Home Team in function of Mean Free Throw Percentage by Home Team on previous 3 games and Mean Three Point Percentage by Home Team on previous 3 games")
axes[0].set_xlabel("Mean Free Throw Percentage by Home Team on previous 3 games")
axes[0].legend(["Home Team Win", "Home Team Lose"])
axes[0].set_ylabel("Mean Three Point Percentage by Home Team on previous 3 games");


# Start with positve examples
axes[1].scatter(df['FT_PCT_home_10g'][df['HOME_TEAM_WINS']==1], 
            df['FG3_PCT_home_10g'][df['HOME_TEAM_WINS']==1], 
            c="salmon") 

# Now for negative examples,
axes[1].scatter(df['FT_PCT_home_10g'][df['HOME_TEAM_WINS']==0], 
            df['FG3_PCT_home_10g'][df['HOME_TEAM_WINS']==0], 
            c="lightblue") 


axes[1].set_title("Win/Lose by Home Team in function of Mean Free Throw Percentage by Home Team on previous 10 games and Mean Three Point Percentage by Home Team on previous 10 games")
axes[1].set_xlabel("Mean Free Throw Percentage by Home Team on previous 10 games")
axes[1].legend(["Home Team Win", "Home Team Lose"])
axes[1].set_ylabel("Mean Three Point Percentage by Home Team on previous 10 games");

# %%
# Conclusion: Look like the number of previous game for game stats does not matter
# but we also can see that the relationship between free throw percentange & three points percentage
# doesn't affect the target variable very significantly too since the points for win case and lose case
# overlap a lot.

# %% [markdown]
# ### Correlation Matrix

# %%
# Find the correlation between our independent variables
corr_matrix = df.corr()
corr_matrix
# Out:
#                          G_home  W_PCT_home  HOME_RECORD_home  \
# G_home                 1.000000    0.066523          0.076809
# W_PCT_home             0.066523    1.000000          0.900035
# HOME_RECORD_home       0.076809    0.900035          1.000000
# ROAD_RECORD_home       0.041533    0.892503          0.617204
# W_PCT_prev_home        0.047540    0.612903          0.543775
# HOME_RECORD_prev_home  0.048936    0.568903          0.512036
# ROAD_RECORD_prev_home  0.039931    0.585232          0.511275
# G_away                 0.953875    0.073556          0.079138
# W_PCT_away             0.057225    0.028726          0.036764
# HOME_RECORD_away       0.074974    0.020036          0.036367
# ROAD_RECORD_away       0.035697    0.032531          0.029904
# W_PCT_prev_away        0.043301    0.021742          0.026648
# HOME_RECORD_prev_away  0.044328    0.021232          0.030918
# ROAD_RECORD_prev_away  0.036550    0.019519          0.018464
# WIN_PRCT_home_3g      -0.012190    0.464078          0.406394
# PTS_home_3g           -0.029054    0.198021          0.150729
# FG_PCT_home_3g        -0.041622    0.240714          0.211973
# FT_PCT_home_3g        -0.039858    0.069751          0.055336
# FG3_PCT_home_3g       -0.039250    0.142585          0.127480
# AST_home_3g           -0.044994    0.157701          0.112551
# REB_home_3g           -0.013778    0.104825          0.080589
# WIN_PRCT_away_3g       0.007340    0.012371          0.019195
# PTS_away_3g           -0.019689    0.005115         -0.019802
# FG_PCT_away_3g        -0.030172   -0.003351          0.002918
# FT_PCT_away_3g        -0.043850    0.013015          0.000673
# FG3_PCT_away_3g       -0.016339   -0.006595         -0.009698
# AST_away_3g           -0.033109   -0.018758         -0.029035
# REB_away_3g            0.001591    0.009414         -0.005775
# WIN_PRCT_home_10g     -0.008327    0.718007          0.638820
# PTS_home_10g          -0.018949    0.254342          0.200974
# FG_PCT_home_10g       -0.028398    0.374598          0.336883
# FT_PCT_home_10g       -0.047721    0.114983          0.095159
# FG3_PCT_home_10g      -0.031493    0.240401          0.217614
# AST_home_10g          -0.032825    0.207713          0.153317
# REB_home_10g          -0.025817    0.157920          0.123315
# WIN_PRCT_away_10g      0.002171    0.022867          0.031021
# PTS_away_10g          -0.011117    0.013072         -0.019327
# FG_PCT_away_10g       -0.014459    0.013834          0.016475
# FT_PCT_away_10g       -0.051263    0.010240         -0.004409
# FG3_PCT_away_10g      -0.027482   -0.001101         -0.003332
# AST_away_10g          -0.020848   -0.008980         -0.028522
# REB_away_10g          -0.015033    0.006576         -0.016035
# SEASON                -0.042066   -0.004524         -0.063577
# HOME_TEAM_WINS         0.005769    0.246197          0.226848
#
#                        ROAD_RECORD_home  W_PCT_prev_home  \
# G_home                         0.041533         0.047540
# W_PCT_home                     0.892503         0.612903
# HOME_RECORD_home               0.617204         0.543775
# ROAD_RECORD_home               1.000000         0.556188
# W_PCT_prev_home                0.556188         1.000000
# HOME_RECORD_prev_home          0.508213         0.945812
# ROAD_RECORD_prev_home          0.539836         0.935597
# G_away                         0.050367         0.055032
# W_PCT_away                     0.012738         0.019945
# HOME_RECORD_away              -0.002277         0.016509
# ROAD_RECORD_away               0.026644         0.021465
# W_PCT_prev_away                0.011322        -0.010441
# HOME_RECORD_prev_away          0.006460        -0.009158
# ROAD_RECORD_prev_away          0.015302        -0.010562
# WIN_PRCT_home_3g               0.421963         0.260976
# PTS_home_3g                    0.202926         0.106293
# FG_PCT_home_3g                 0.216819         0.149829
# FT_PCT_home_3g                 0.071675         0.057253
# FG3_PCT_home_3g                0.128063         0.078101
# AST_home_3g                    0.168144         0.106925
# REB_home_3g                    0.105585         0.025877
# WIN_PRCT_away_3g               0.001901         0.011205
# PTS_away_3g                    0.029288         0.003755
# FG_PCT_away_3g                -0.007595         0.005747
# FT_PCT_away_3g                 0.024124        -0.001920
# FG3_PCT_away_3g               -0.001035        -0.006856
# AST_away_3g                   -0.003814        -0.012989
# REB_away_3g                    0.020246         0.002925
# WIN_PRCT_home_10g              0.646201         0.404636
# PTS_home_10g                   0.254924         0.136817
# FG_PCT_home_10g                0.330883         0.239794
# FT_PCT_home_10g                0.115782         0.093030
# FG3_PCT_home_10g               0.215573         0.136004
# AST_home_10g                   0.217716         0.144248
# REB_home_10g                   0.158051         0.038710
# WIN_PRCT_away_10g              0.008777         0.020268
# PTS_away_10g                   0.043568         0.013470
# FG_PCT_away_10g                0.009889         0.018010
# FT_PCT_away_10g                0.024741         0.005972
# FG3_PCT_away_10g               0.003162        -0.003216
# AST_away_10g                   0.014018        -0.011343
# REB_away_10g                   0.025994         0.002824
# SEASON                         0.057257        -0.005695
# HOME_TEAM_WINS                 0.215029         0.178680
#
#                        HOME_RECORD_prev_home  ROAD_RECORD_prev_home    G_away  \
# G_home                              0.048936               0.039931  0.953875
# W_PCT_home                          0.568903               0.585232  0.073556
# HOME_RECORD_home                    0.512036               0.511275  0.079138
# ROAD_RECORD_home                    0.508213               0.539836  0.050367
# W_PCT_prev_home                     0.945812               0.935597  0.055032
# HOME_RECORD_prev_home               1.000000               0.770283  0.055633
# ROAD_RECORD_prev_home               0.770283               1.000000  0.047389
# G_away                              0.055633               0.047389  1.000000
# W_PCT_away                          0.018113               0.019480  0.058630
# HOME_RECORD_away                    0.020258               0.010268  0.078166
# ROAD_RECORD_away                    0.014303               0.026751  0.035823
# W_PCT_prev_away                    -0.008605              -0.011213  0.044374
# HOME_RECORD_prev_away              -0.002878              -0.015052  0.045472
# ROAD_RECORD_prev_away              -0.013921              -0.005518  0.037402
# WIN_PRCT_home_3g                    0.239059               0.252703 -0.006042
# PTS_home_3g                         0.075247               0.127652 -0.022641
# FG_PCT_home_3g                      0.138292               0.144067 -0.039310
# FT_PCT_home_3g                      0.040335               0.069005 -0.039929
# FG3_PCT_home_3g                     0.065948               0.081878 -0.037904
# AST_home_3g                         0.076357               0.127270 -0.039876
# REB_home_3g                         0.008952               0.041336 -0.009529
# WIN_PRCT_away_3g                    0.010557               0.010474  0.008882
# PTS_away_3g                        -0.019924               0.029646 -0.014883
# FG_PCT_away_3g                      0.004067               0.006982 -0.027119
# FT_PCT_away_3g                     -0.008949               0.006125 -0.046284
# FG3_PCT_away_3g                    -0.006097              -0.006803 -0.013224
# AST_away_3g                        -0.030232               0.007762 -0.029916
# REB_away_3g                        -0.011690               0.018757  0.004471
# WIN_PRCT_home_10g                   0.372156               0.390182 -0.003429
# PTS_home_10g                        0.098402               0.162581 -0.013175
# FG_PCT_home_10g                     0.222103               0.229671 -0.023912
# FT_PCT_home_10g                     0.069021               0.108233 -0.046848
# FG3_PCT_home_10g                    0.120091               0.136872 -0.029272
# AST_home_10g                        0.104480               0.170012 -0.026654
# REB_home_10g                        0.014634               0.060524 -0.021113
# WIN_PRCT_away_10g                   0.018092               0.020162  0.001185
# PTS_away_10g                       -0.020685               0.049737 -0.007196
# FG_PCT_away_10g                     0.010990               0.023653 -0.013539
# FT_PCT_away_10g                    -0.005258               0.017728 -0.054214
# FG3_PCT_away_10g                   -0.009425               0.004065 -0.027635
# AST_away_10g                       -0.036609               0.018112 -0.018833
# REB_away_10g                       -0.017317               0.024777 -0.015085
# SEASON                             -0.059460               0.054535 -0.038070
# HOME_TEAM_WINS                      0.167023               0.169314  0.007242
#
#                        W_PCT_away  HOME_RECORD_away  ...  REB_home_10g  \
# G_home                   0.057225          0.074974  ...     -0.025817
# W_PCT_home               0.028726          0.020036  ...      0.157920
# HOME_RECORD_home         0.036764          0.036367  ...      0.123315
# ROAD_RECORD_home         0.012738         -0.002277  ...      0.158051
# W_PCT_prev_home          0.019945          0.016509  ...      0.038710
# HOME_RECORD_prev_home    0.018113          0.020258  ...      0.014634
# ROAD_RECORD_prev_home    0.019480          0.010268  ...      0.060524
# G_away                   0.058630          0.078166  ...     -0.021113
# W_PCT_away               1.000000          0.903265  ...      0.000538
# HOME_RECORD_away         0.903265          1.000000  ...     -0.024932
# ROAD_RECORD_away         0.885270          0.610731  ...      0.026543
# W_PCT_prev_away          0.612401          0.542894  ...      0.004389
# HOME_RECORD_prev_away    0.567607          0.510423  ...     -0.018966
# ROAD_RECORD_prev_away    0.584809          0.510524  ...      0.029605
# WIN_PRCT_home_3g         0.002987         -0.000207  ...      0.155210
# PTS_home_3g             -0.000345         -0.032607  ...      0.327090
# FG_PCT_home_3g          -0.003804         -0.008602  ...     -0.049555
# FT_PCT_home_3g           0.007403         -0.007490  ...     -0.012124
# FG3_PCT_home_3g         -0.004855         -0.009776  ...     -0.028288
# AST_home_3g             -0.017990         -0.032412  ...      0.179161
# REB_home_3g             -0.010573         -0.029290  ...      0.690258
# WIN_PRCT_away_3g         0.478598          0.432685  ...      0.005338
# PTS_away_3g              0.208142          0.167173  ...      0.217587
# FG_PCT_away_3g           0.251961          0.229019  ...      0.011984
# FT_PCT_away_3g           0.090400          0.077662  ...      0.048107
# FG3_PCT_away_3g          0.139984          0.126820  ...      0.005893
# AST_away_3g              0.159908          0.120205  ...      0.156630
# REB_away_3g              0.110451          0.085379  ...      0.147745
# WIN_PRCT_home_10g        0.015201          0.006637  ...      0.236239
# PTS_home_10g             0.010942         -0.030052  ...      0.407660
# FG_PCT_home_10g          0.007974         -0.002172  ...     -0.079102
# FT_PCT_home_10g          0.005590         -0.009745  ...     -0.023638
# FG3_PCT_home_10g        -0.006241         -0.015726  ...     -0.061314
# AST_home_10g            -0.006108         -0.030904  ...      0.233793
# REB_home_10g             0.000538         -0.024932  ...      1.000000
# WIN_PRCT_away_10g        0.721407          0.649090  ...      0.002583
# PTS_away_10g             0.259693          0.208620  ...      0.262055
# FG_PCT_away_10g          0.383563          0.346640  ...      0.011441
# FT_PCT_away_10g          0.118298          0.101581  ...      0.061230
# FG3_PCT_away_10g         0.249819          0.223197  ...      0.004213
# AST_away_10g             0.213211          0.161221  ...      0.197731
# REB_away_10g             0.156027          0.122842  ...      0.209480
# SEASON                  -0.001347         -0.063311  ...      0.428856
# HOME_TEAM_WINS          -0.210977         -0.187169  ...      0.035532
#
#                        WIN_PRCT_away_10g  PTS_away_10g  FG_PCT_away_10g  \
# G_home                          0.002171     -0.011117        -0.014459
# W_PCT_home                      0.022867      0.013072         0.013834
# HOME_RECORD_home                0.031021     -0.019327         0.016475
# ROAD_RECORD_home                0.008777      0.043568         0.009889
# W_PCT_prev_home                 0.020268      0.013470         0.018010
# HOME_RECORD_prev_home           0.018092     -0.020685         0.010990
# ROAD_RECORD_prev_home           0.020162      0.049737         0.023653
# G_away                          0.001185     -0.007196        -0.013539
# W_PCT_away                      0.721407      0.259693         0.383563
# HOME_RECORD_away                0.649090      0.208620         0.346640
# ROAD_RECORD_away                0.638222      0.254932         0.334330
# W_PCT_prev_away                 0.414133      0.143183         0.254500
# HOME_RECORD_prev_away           0.381717      0.108111         0.238690
# ROAD_RECORD_prev_away           0.397844      0.164307         0.240191
# WIN_PRCT_home_3g               -0.007093      0.005647         0.001531
# PTS_home_3g                     0.004259      0.379985         0.101990
# FG_PCT_home_3g                  0.006042      0.084827         0.060234
# FT_PCT_home_3g                  0.012290      0.093296         0.036856
# FG3_PCT_home_3g                 0.003544      0.043662         0.020940
# AST_home_3g                    -0.006890      0.247834         0.055761
# REB_home_3g                    -0.011137      0.183107         0.005513
# WIN_PRCT_away_3g                0.665587      0.237133         0.343180
# PTS_away_3g                     0.288683      0.798670         0.461551
# FG_PCT_away_3g                  0.338370      0.380525         0.659824
# FT_PCT_away_3g                  0.103439      0.183173         0.089474
# FG3_PCT_away_3g                 0.203053      0.211432         0.278309
# AST_away_3g                     0.216924      0.493655         0.390098
# REB_away_3g                     0.163704      0.275388        -0.055296
# WIN_PRCT_home_10g               0.005280      0.005789         0.014779
# PTS_home_10g                    0.015726      0.462850         0.126565
# FG_PCT_home_10g                 0.019134      0.118801         0.095777
# FT_PCT_home_10g                 0.010000      0.139646         0.073448
# FG3_PCT_home_10g                0.001941      0.063022         0.041400
# AST_home_10g                    0.004780      0.316782         0.076935
# REB_home_10g                    0.002583      0.262055         0.011441
# WIN_PRCT_away_10g               1.000000      0.355778         0.512991
# PTS_away_10g                    0.355778      1.000000         0.579077
# FG_PCT_away_10g                 0.512991      0.579077         1.000000
# FT_PCT_away_10g                 0.135572      0.271037         0.130809
# FG3_PCT_away_10g                0.361927      0.374160         0.482321
# AST_away_10g                    0.291722      0.652762         0.521399
# REB_away_10g                    0.235369      0.407542        -0.070387
# SEASON                         -0.002090      0.558201         0.058651
# HOME_TEAM_WINS                 -0.174070     -0.086213        -0.107581
#
#                        FT_PCT_away_10g  FG3_PCT_away_10g  AST_away_10g  \
# G_home                       -0.051263         -0.027482     -0.020848
# W_PCT_home                    0.010240         -0.001101     -0.008980
# HOME_RECORD_home             -0.004409         -0.003332     -0.028522
# ROAD_RECORD_home              0.024741          0.003162      0.014018
# W_PCT_prev_home               0.005972         -0.003216     -0.011343
# HOME_RECORD_prev_home        -0.005258         -0.009425     -0.036609
# ROAD_RECORD_prev_home         0.017728          0.004065      0.018112
# G_away                       -0.054214         -0.027635     -0.018833
# W_PCT_away                    0.118298          0.249819      0.213211
# HOME_RECORD_away              0.101581          0.223197      0.161221
# ROAD_RECORD_away              0.112429          0.224435      0.218421
# W_PCT_prev_away               0.091522          0.143992      0.150180
# HOME_RECORD_prev_away         0.066078          0.132099      0.112389
# ROAD_RECORD_prev_away         0.108255          0.139381      0.172800
# WIN_PRCT_home_3g              0.013591          0.004764      0.001938
# PTS_home_3g                   0.119707          0.050906      0.259666
# FG_PCT_home_3g                0.060635          0.035005      0.051670
# FT_PCT_home_3g                0.027426          0.022108      0.070872
# FG3_PCT_home_3g               0.030345          0.018058      0.026221
# AST_home_3g                   0.077543          0.028560      0.184376
# REB_home_3g                   0.042907          0.004108      0.134491
# WIN_PRCT_away_3g              0.084061          0.247658      0.195043
# PTS_away_3g                   0.212336          0.307001      0.525730
# FG_PCT_away_3g                0.083706          0.326069      0.349282
# FT_PCT_away_3g                0.667535          0.093632      0.096515
# FG3_PCT_away_3g               0.076461          0.591231      0.184627
# AST_away_3g                   0.100395          0.241724      0.761854
# REB_away_3g                  -0.029810         -0.042869      0.153188
# WIN_PRCT_home_10g             0.014118          0.005466      0.006554
# PTS_home_10g                  0.141370          0.064844      0.318583
# FG_PCT_home_10g               0.075063          0.049674      0.072541
# FT_PCT_home_10g               0.047522          0.039708      0.102262
# FG3_PCT_home_10g              0.046510          0.030499      0.038558
# AST_home_10g                  0.105267          0.042619      0.234519
# REB_home_10g                  0.061230          0.004213      0.197731
# WIN_PRCT_away_10g             0.135572          0.361927      0.291722
# PTS_away_10g                  0.271037          0.374160      0.652762
# FG_PCT_away_10g               0.130809          0.482321      0.521399
# FT_PCT_away_10g               1.000000          0.137577      0.138104
# FG3_PCT_away_10g              0.137577          1.000000      0.315177
# AST_away_10g                  0.138104          0.315177      1.000000
# REB_away_10g                 -0.033617         -0.052021      0.232992
# SEASON                        0.143454          0.046760      0.419757
# HOME_TEAM_WINS               -0.030161         -0.071854     -0.081052
#
#                        REB_away_10g    SEASON  HOME_TEAM_WINS
# G_home                    -0.015033 -0.042066        0.005769
# W_PCT_home                 0.006576 -0.004524        0.246197
# HOME_RECORD_home          -0.016035 -0.063577        0.226848
# ROAD_RECORD_home           0.025994  0.057257        0.215029
# W_PCT_prev_home            0.002824 -0.005695        0.178680
# HOME_RECORD_prev_home     -0.017317 -0.059460        0.167023
# ROAD_RECORD_prev_home      0.024777  0.054535        0.169314
# G_away                    -0.015085 -0.038070        0.007242
# W_PCT_away                 0.156027 -0.001347       -0.210977
# HOME_RECORD_away           0.122842 -0.063311       -0.187169
# ROAD_RECORD_away           0.154529  0.064134       -0.189912
# W_PCT_prev_away            0.030546 -0.003861       -0.152556
# HOME_RECORD_prev_away      0.005468 -0.055778       -0.138481
# ROAD_RECORD_prev_away      0.054401  0.054106       -0.148942
# WIN_PRCT_home_3g          -0.003182 -0.002540        0.135006
# PTS_home_3g                0.204928  0.451164        0.058787
# FG_PCT_home_3g             0.008072  0.033967        0.087348
# FT_PCT_home_3g             0.041896  0.101776        0.030939
# FG3_PCT_home_3g            0.009262  0.030860        0.051182
# AST_home_3g                0.151162  0.326610        0.047870
# REB_home_3g                0.141542  0.298570        0.026973
# WIN_PRCT_away_3g           0.156945  0.001001       -0.114742
# PTS_away_3g                0.333721  0.449376       -0.074401
# FG_PCT_away_3g            -0.040894  0.036530       -0.081498
# FT_PCT_away_3g            -0.014844  0.094523       -0.020427
# FG3_PCT_away_3g           -0.029376  0.016690       -0.035840
# AST_away_3g                0.180175  0.319519       -0.064374
# REB_away_3g                0.690345  0.293403       -0.035862
# WIN_PRCT_home_10g         -0.009397 -0.003208        0.202476
# PTS_home_10g               0.256202  0.557246        0.072310
# FG_PCT_home_10g            0.008809  0.043637        0.129364
# FT_PCT_home_10g            0.049994  0.147410        0.034792
# FG3_PCT_home_10g           0.009596  0.033259        0.079163
# AST_home_10g               0.198334  0.417578        0.064238
# REB_home_10g               0.209480  0.428856        0.035532
# WIN_PRCT_away_10g          0.235369 -0.002090       -0.174070
# PTS_away_10g               0.407542  0.558201       -0.086213
# FG_PCT_away_10g           -0.070387  0.058651       -0.107581
# FT_PCT_away_10g           -0.033617  0.143454       -0.030161
# FG3_PCT_away_10g          -0.052021  0.046760       -0.071854
# AST_away_10g               0.232992  0.419757       -0.081052
# REB_away_10g               1.000000  0.416745       -0.053196
# SEASON                     0.416745  1.000000       -0.031014
# HOME_TEAM_WINS            -0.053196 -0.031014        1.000000
#
# [44 rows x 44 columns]

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(corr_matrix, 
            annot=True, 
            linewidths=0.5, 
            fmt= ".2f", 
            cmap="YlGnBu");
